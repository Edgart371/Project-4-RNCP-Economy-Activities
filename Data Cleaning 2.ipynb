# %%
#First step import usefull library

import pandas as pd
import numpy as np

# %% [markdown]
# ## Production Activities
# ### For the file (Export of goods and services total and by product (2016).xlsx)

# %%
#Import data using pandas
pa_exports=pd.read_excel(r"/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Production Activities/Export of goods and services total and by product (2016).xlsx")
pa_exports
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                                 NaN
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Liste the name of columns
pa_exports.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 246', 'Unnamed: 247', 'Unnamed: 248', 'Unnamed: 249',
#        'Unnamed: 250', 'Unnamed: 251', 'Unnamed: 252', 'Unnamed: 253',
#        'Unnamed: 254', 'Unnamed: 255'],
#       dtype='object', length=256)

# %%
#Place the name "Years" on the row that i will have the columns name, then drop the rest of columns and rows
pa_exports.loc[pa_exports.index[6], 'Unnamed: 0'] = "Years"
pa_exports
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                               Years
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Delete all rows with data not relevant
pa_exports = pa_exports.drop(labels=range(0, 6), axis=0)
pa_exports
# Out:
#                                            Unnamed: 0        Unnamed: 1  \
# 6                                               Years             Total
# 7                                                1995           20739.8
# 8                                                1996           21916.8
# 9                                                1997           24341.6
# 10                                               1998           26254.6
# 11                                               1999           27488.5
# 12                                               2000           31384.6
# 13                                               2001           32049.8
# 14                                               2002           33406.7
# 15                                               2003           35003.8
# 16                                               2004           36837.8
# 17                                               2005           37637.5
# ...

# %%
#Delete all rows with data not relevant
pa_exports = pa_exports.drop(labels=range(32, 54), axis=0)
pa_exports
# Out:
#    Unnamed: 0 Unnamed: 1                                     Unnamed: 2  \
# 6       Years      Total  Products of agriculture, forestry and fishing
# 7        1995    20739.8                                          222.2
# 8        1996    21916.8                                          224.5
# 9        1997    24341.6                                          289.8
# 10       1998    26254.6                                          290.2
# 11       1999    27488.5                                          299.8
# 12       2000    31384.6                                            360
# 13       2001    32049.8                                          450.7
# 14       2002    33406.7                                            488
# 15       2003    35003.8                                          523.2
# 16       2004    36837.8                                          592.6
# 17       2005    37637.5                                          594.2
# ...

# %%
#Delete all columns with NAN values
pa_exports = pa_exports.dropna(thresh=10, axis=1)
pa_exports
# Out:
#    Unnamed: 0 Unnamed: 1                                     Unnamed: 2  \
# 6       Years      Total  Products of agriculture, forestry and fishing
# 7        1995    20739.8                                          222.2
# 8        1996    21916.8                                          224.5
# 9        1997    24341.6                                          289.8
# 10       1998    26254.6                                          290.2
# 11       1999    27488.5                                          299.8
# 12       2000    31384.6                                            360
# 13       2001    32049.8                                          450.7
# 14       2002    33406.7                                            488
# 15       2003    35003.8                                          523.2
# 16       2004    36837.8                                          592.6
# 17       2005    37637.5                                          594.2
# ...

# %%
#Rename the columns name with the values of the row index 6 
pa_exports.rename(columns=pa_exports.iloc[0], inplace = True)
pa_exports
# Out:
# /Users/edgartome_1/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     Years    Total  Products of agriculture, forestry and fishing  \
# 6   Years    Total  Products of agriculture, forestry and fishing
# 7    1995  20739.8                                          222.2
# 8    1996  21916.8                                          224.5
# 9    1997  24341.6                                          289.8
# 10   1998  26254.6                                          290.2
# 11   1999  27488.5                                          299.8
# 12   2000  31384.6                                            360
# 13   2001  32049.8                                          450.7
# ...

# %%
pa_exports.columns = ['Col_' + str(i) if 3 <= i <= 39 else x for i, x in enumerate(pa_exports.columns, 1)]
pa_exports
# Out:
#     Years    Total                                          Col_3  \
# 6   Years    Total  Products of agriculture, forestry and fishing
# 7    1995  20739.8                                          222.2
# 8    1996  21916.8                                          224.5
# 9    1997  24341.6                                          289.8
# 10   1998  26254.6                                          290.2
# 11   1999  27488.5                                          299.8
# 12   2000  31384.6                                            360
# 13   2001  32049.8                                          450.7
# 14   2002  33406.7                                            488
# 15   2003  35003.8                                          523.2
# 16   2004  36837.8                                          592.6
# 17   2005  37637.5                                          594.2
# 18   2006  44734.8                                          664.6
# ...

# %%
#Reset index
pa_exports = pa_exports.reset_index()
pa_exports
# Out:
#     index  Years    Total                                          Col_3  \
# 0       6  Years    Total  Products of agriculture, forestry and fishing
# 1       7   1995  20739.8                                          222.2
# 2       8   1996  21916.8                                          224.5
# 3       9   1997  24341.6                                          289.8
# 4      10   1998  26254.6                                          290.2
# 5      11   1999  27488.5                                          299.8
# 6      12   2000  31384.6                                            360
# 7      13   2001  32049.8                                          450.7
# 8      14   2002  33406.7                                            488
# 9      15   2003  35003.8                                          523.2
# 10     16   2004  36837.8                                          592.6
# 11     17   2005  37637.5                                          594.2
# ...

# %%
#Delete old index
pa_exports = pa_exports.drop(labels=['index'], axis=1)
pa_exports
# Out:
#     Years    Total                                          Col_3  \
# 0   Years    Total  Products of agriculture, forestry and fishing
# 1    1995  20739.8                                          222.2
# 2    1996  21916.8                                          224.5
# 3    1997  24341.6                                          289.8
# 4    1998  26254.6                                          290.2
# 5    1999  27488.5                                          299.8
# 6    2000  31384.6                                            360
# 7    2001  32049.8                                          450.7
# 8    2002  33406.7                                            488
# 9    2003  35003.8                                          523.2
# 10   2004  36837.8                                          592.6
# 11   2005  37637.5                                          594.2
# 12   2006  44734.8                                          664.6
# ...

# %%
#Delete old columns name
pa_exports = pa_exports.drop(labels=[0], axis=0)
pa_exports
# Out:
#    Years    Total   Col_3  Col_4   Col_5   Col_6   Col_7   Col_8   Col_9  \
# 1   1995  20739.8   222.2  257.7  1201.4  5170.8  1865.2   552.1     743
# 2   1996  21916.8   224.5  214.4  1306.5  5428.9  1718.1   430.6   714.4
# 3   1997  24341.6   289.8  240.3  1413.6  5864.1  1954.9   472.2   884.3
# 4   1998  26254.6   290.2  172.6  1480.4  6038.2  2062.9   359.5   856.9
# 5   1999  27488.5   299.8  166.2  1545.4  6074.8  2130.7   393.9   881.8
# 6   2000  31384.6     360  183.2  1761.4  6275.2  2654.4   620.4  1174.5
# 7   2001  32049.8   450.7  173.4  1799.6  6446.2  2527.6     492  1039.5
# 8   2002  33406.7     488  165.9  1981.6  6237.5  2575.4   531.2  1127.5
# 9   2003  35003.8   523.2  160.8  2021.5  5903.3  2628.1   648.3  1285.1
# 10  2004  36837.8   592.6  266.3  2146.7  5573.3  2627.2   763.6  1545.2
# 11  2005  37637.5   594.2  325.3    2341    5006    2632  1130.8  1804.8
# 12  2006  44734.8   664.6  549.7  2723.1    5266  2930.7  1697.2  2033.8
# ...

# %%
#Export to CSV file
pa_exports.to_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Production Activities/Export_of_goods.csv', index=False)

# %% [markdown]
# ### For the file (Import of goods and services total and by product (2016).xlsx)

# %%
#Import data using pandas
pa_imports=pd.read_excel(r"/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Production Activities/Import of goods and services total and by product (2016).xlsx")
pa_imports
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                                 NaN
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Place the name "Years" on the row that i will have the columns name, then drop the rest of columns and rows
pa_imports.loc[pa_imports.index[6], 'Unnamed: 0'] = "Years"
pa_imports
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                               Years
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Place the name "Years" on the row that i will have the columns name, then drop the rest of columns and rows
pa_imports.loc[pa_imports.index[6], 'Unnamed: 0'] = "Years"
pa_imports
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                               Years
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Delete all rows with data not relevant
pa_imports = pa_imports.drop(labels=range(0, 6), axis=0)
pa_imports
# Out:
#                                            Unnamed: 0        Unnamed: 1  \
# 6                                               Years             Total
# 7                                                1995             28397
# 8                                                1996             30524
# 9                                                1997           34732.1
# 10                                               1998           39234.4
# 11                                               1999           42675.7
# 12                                               2000           48851.4
# 13                                               2001           49644.6
# 14                                               2002           48849.2
# 15                                               2003           48056.4
# 16                                               2004           52786.5
# 17                                               2005           55379.3
# ...

# %%
#Delete all rows with data not relevant
pa_imports = pa_imports.drop(labels=range(32, 54), axis=0)
pa_imports
# Out:
#    Unnamed: 0 Unnamed: 1                                     Unnamed: 2  \
# 6       Years      Total  Products of agriculture, forestry and fishing
# 7        1995      28397                                         1765.1
# 8        1996      30524                                         1873.4
# 9        1997    34732.1                                         1956.9
# 10       1998    39234.4                                         2205.6
# 11       1999    42675.7                                         2017.5
# 12       2000    48851.4                                         2183.6
# 13       2001    49644.6                                         2375.2
# 14       2002    48849.2                                         2299.8
# 15       2003    48056.4                                         2183.4
# 16       2004    52786.5                                         2263.8
# 17       2005    55379.3                                         2215.9
# ...

# %%
#Delete all columns with NAN values
pa_imports = pa_imports.dropna(thresh=10, axis=1)
pa_imports
# Out:
#    Unnamed: 0 Unnamed: 1                                     Unnamed: 2  \
# 6       Years      Total  Products of agriculture, forestry and fishing
# 7        1995      28397                                         1765.1
# 8        1996      30524                                         1873.4
# 9        1997    34732.1                                         1956.9
# 10       1998    39234.4                                         2205.6
# 11       1999    42675.7                                         2017.5
# 12       2000    48851.4                                         2183.6
# 13       2001    49644.6                                         2375.2
# 14       2002    48849.2                                         2299.8
# 15       2003    48056.4                                         2183.4
# 16       2004    52786.5                                         2263.8
# 17       2005    55379.3                                         2215.9
# ...

# %%
#Rename the columns name with the values of the row index 6 
pa_imports.rename(columns=pa_imports.iloc[0], inplace = True)
pa_imports
# Out:
# /Users/edgartome_1/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     Years    Total  Products of agriculture, forestry and fishing  \
# 6   Years    Total  Products of agriculture, forestry and fishing
# 7    1995    28397                                         1765.1
# 8    1996    30524                                         1873.4
# 9    1997  34732.1                                         1956.9
# 10   1998  39234.4                                         2205.6
# 11   1999  42675.7                                         2017.5
# 12   2000  48851.4                                         2183.6
# 13   2001  49644.6                                         2375.2
# ...

# %%
pa_imports.columns = ['Col_' + str(i) if 3 <= i <= 39 else x for i, x in enumerate(pa_imports.columns, 1)]
pa_imports
# Out:
#     Years    Total                                          Col_3  \
# 6   Years    Total  Products of agriculture, forestry and fishing
# 7    1995    28397                                         1765.1
# 8    1996    30524                                         1873.4
# 9    1997  34732.1                                         1956.9
# 10   1998  39234.4                                         2205.6
# 11   1999  42675.7                                         2017.5
# 12   2000  48851.4                                         2183.6
# 13   2001  49644.6                                         2375.2
# 14   2002  48849.2                                         2299.8
# 15   2003  48056.4                                         2183.4
# 16   2004  52786.5                                         2263.8
# 17   2005  55379.3                                         2215.9
# 18   2006    61897                                         2325.9
# ...

# %%
#Reset index
pa_imports = pa_imports.reset_index()
pa_imports
# Out:
#     index  Years    Total                                          Col_3  \
# 0       6  Years    Total  Products of agriculture, forestry and fishing
# 1       7   1995    28397                                         1765.1
# 2       8   1996    30524                                         1873.4
# 3       9   1997  34732.1                                         1956.9
# 4      10   1998  39234.4                                         2205.6
# 5      11   1999  42675.7                                         2017.5
# 6      12   2000  48851.4                                         2183.6
# 7      13   2001  49644.6                                         2375.2
# 8      14   2002  48849.2                                         2299.8
# 9      15   2003  48056.4                                         2183.4
# 10     16   2004  52786.5                                         2263.8
# 11     17   2005  55379.3                                         2215.9
# ...

# %%
#Delete old index
pa_imports = pa_imports.drop(labels=['index'], axis=1)
pa_imports
# Out:
#     Years    Total                                          Col_3  \
# 0   Years    Total  Products of agriculture, forestry and fishing
# 1    1995    28397                                         1765.1
# 2    1996    30524                                         1873.4
# 3    1997  34732.1                                         1956.9
# 4    1998  39234.4                                         2205.6
# 5    1999  42675.7                                         2017.5
# 6    2000  48851.4                                         2183.6
# 7    2001  49644.6                                         2375.2
# 8    2002  48849.2                                         2299.8
# 9    2003  48056.4                                         2183.4
# 10   2004  52786.5                                         2263.8
# 11   2005  55379.3                                         2215.9
# 12   2006    61897                                         2325.9
# ...

# %%
#Delete old columns name
pa_imports = pa_imports.drop(labels=[0], axis=0)
pa_imports
# Out:
#    Years    Total   Col_3   Col_4   Col_5   Col_6   Col_7   Col_8   Col_9  \
# 1   1995    28397  1765.1  1536.7  2404.8  2286.4   788.4   642.9  2219.9
# 2   1996    30524  1873.4  1547.1  2583.5  2478.3   839.4   675.6  2283.8
# 3   1997  34732.1  1956.9  1876.3  2750.5  2816.8   946.4   698.5  2567.6
# 4   1998  39234.4  2205.6  1426.1  3194.5  3181.9  1108.3   634.1  2761.5
# 5   1999  42675.7  2017.5  1987.5  3521.7  3200.8  1216.4   773.6    2810
# 6   2000  48851.4  2183.6  3298.9    3645  3606.7  1449.2  1381.5  3207.1
# 7   2001  49644.6  2375.2  3239.3  3904.3  3800.6  1510.6  1337.1    3286
# 8   2002  48849.2  2299.8  2946.7  3911.4  3761.2  1503.9  1387.9  3412.7
# 9   2003  48056.4  2183.4  3154.4    3942  3608.9  1460.4  1254.4  3444.7
# 10  2004  52786.5  2263.8  3852.9  4166.6  3645.2  1539.4  1306.5    3727
# 11  2005  55379.3  2215.9    5112  4187.6  3398.1  1556.5  1939.2  3960.5
# 12  2006    61897  2325.9  6239.1  4730.2  3766.1  1659.4  1975.2  4404.8
# ...

# %%
#Export to CSV file
pa_imports.to_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Production Activities/Import_of_goods.csv', index=False)

# %% [markdown]
# ### For the file (Gross value of production total and by industry (2016).xlsx)

# %%
#Import data using pandas
pa_production=pd.read_excel(r"/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Production Activities/Gross value of production total and by industry (2016).xlsx")
pa_production
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                                 NaN
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Place the name "Years" on the row that i will have the columns name, then drop the rest of columns and rows
pa_production.loc[pa_production.index[6], 'Unnamed: 0'] = "Years"

#Delete all rows with data not relevant
pa_production = pa_production.drop(labels=range(0, 6), axis=0)

#Delete all rows with data not relevant
pa_production = pa_production.drop(labels=range(32, 54), axis=0)

#Delete all columns with NAN values
pa_production = pa_production.dropna(thresh=10, axis=1)

#Rename the columns name with the values of the row index 6 
pa_production.rename(columns=pa_production.iloc[0], inplace = True)

#Rename the columns by code "Col_" plus position
pa_production.columns = ['Col_' + str(i) if 3 <= i <= 39 else x for i, x in enumerate(pa_production.columns, 1)]
pa_production

#Reset index
pa_production = pa_production.reset_index()

#Delete old index
pa_production = pa_production.drop(labels=['index'], axis=1)

#Delete old columns name
pa_production = pa_production.drop(labels=[0], axis=0)

#Export to CSV file
pa_production.to_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Production Activities/Production_of_goods.csv', index=False)

pa_production
# Out:
#    Years      Total    Col_3    Col_4     Col_5     Col_6    Col_7    Col_8  \
# 1   1995  171311.82  6847.59   910.94  10031.24  10628.82  5614.63  1783.91
# 2   1996  182948.79   7198.9    859.1  10748.17  10987.72  5447.41  1874.33
# 3   1997  198180.46  6751.11   982.19  10753.41   11545.8  5851.89   2191.4
# 4   1998   212920.6  6832.91  1012.77  11135.14  11644.88   6371.3   1777.1
# 5   1999  224592.74  6978.79  1030.33  11418.83  11320.01  6511.54  2188.51
# 6   2000  245157.91   7093.7   1119.5  11846.41   11635.3   7423.9  3511.26
# 7   2001  259028.36  7308.38  1193.54  12574.69  11827.12  7342.03     3359
# 8   2002  265101.43  7169.71  1118.04  12524.19   11523.3  7126.55  3052.48
# 9   2003  268623.87  7177.79  1049.22  12527.63  11007.41  7125.46   3272.6
# 10  2004  282392.65  7434.19  1163.81  12975.57  10654.22  7136.75  4023.12
# 11  2005  293681.92  7153.66  1289.69   13071.3   9751.27  7239.76  5623.34
# ...

# %% [markdown]
# ## Efficiency and Return
# ### For the file (Apparent labour productivity total and by industry.xlsx)

# %%
#Import data using pandas
ef_productivity=pd.read_excel(r"/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Efficiency and Return/Apparent labour productivity total and by industry.xlsx")
ef_productivity
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                                 NaN
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Place the name "Years" on the row that i will have the columns name, then drop the rest of columns and rows
ef_productivity.loc[ef_productivity.index[6], 'Unnamed: 0'] = "Years"

#Delete all rows with data not relevant
ef_productivity = ef_productivity.drop(labels=range(0, 6), axis=0)

#Delete all rows with data not relevant
ef_productivity = ef_productivity.drop(labels=range(32, 54), axis=0)

#Delete all columns with NAN values
ef_productivity = ef_productivity.dropna(thresh=10, axis=1)

#Rename the columns name with the values of the row index 6 
ef_productivity.rename(columns=ef_productivity.iloc[0], inplace = True)

#Rename the columns by code "Col_" plus position
ef_productivity.columns = ['Col_' + str(i) if 3 <= i <= 39 else x for i, x in enumerate(ef_productivity.columns, 1)]
ef_productivity

#Reset index
ef_productivity = ef_productivity.reset_index()

#Delete old index
ef_productivity = ef_productivity.drop(labels=['index'], axis=1)

#Delete old columns name
ef_productivity = ef_productivity.drop(labels=[0], axis=0)

#Export to CSV file
ef_productivity.to_csv(r'//Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Efficiency and Return/labour_productivity.csv', index=False)
ef_productivity
# Out:
#    Years     Total     Col_3     Col_4     Col_5     Col_6     Col_7  \
# 1   1995  18176.07   9161.38  34275.96  13823.52   9446.11  18950.96
# 2   1996   18880.6   9159.26  30249.94  15590.86  10226.27  18178.73
# 3   1997  19963.27   8239.76  32103.77  16629.32  10434.46   19732.4
# 4   1998  20871.56   8605.59  33141.17  18311.62  10345.16  20836.64
# 5   1999  21990.33   8902.29  32997.47  20902.23  10726.39  21764.65
# 6   2000   23133.1    8809.1  33664.85     20071  10623.54  25647.79
# 7   2001  24183.21    8842.2  34895.48  22226.07  10966.11  25203.06
# 8   2002  25230.05   8967.58  31143.81  24584.47   11785.4  25297.29
# 9   2003  26174.16   9018.98  30072.39  25985.42  12275.85  24996.96
# 10  2004  27474.36   9753.43  35695.46  27291.87  12372.61  25206.05
# 11  2005  28474.63   9223.44  39117.72  28182.04  12280.19  27213.13
# 12  2006  29724.44   9731.23  48522.68  28418.46  12947.86  29893.35
# 13  2007  31535.77   9335.47  49904.61  28248.36  14152.94   32349.9
# ...

# %% [markdown]
# ### For the file (Investment rate total and by industry.xlsx)

# %%
#Import data using pandas
ef_invest=pd.read_excel(r"/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Efficiency and Return/Investment rate total and by industry.xlsx")
ef_invest
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                                 NaN
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Place the name "Years" on the row that i will have the columns name, then drop the rest of columns and rows
ef_invest.loc[ef_invest.index[6], 'Unnamed: 0'] = "Years"

#Delete all rows with data not relevant
ef_invest = ef_invest.drop(labels=range(0, 6), axis=0)

#Delete all rows with data not relevant
ef_invest = ef_invest.drop(labels=range(32, 54), axis=0)

#Delete all columns with NAN values
ef_invest = ef_invest.dropna(thresh=10, axis=1)

#Rename the columns name with the values of the row index 6 
ef_invest.rename(columns=ef_invest.iloc[0], inplace = True)

#Rename the columns by code "Col_" plus position
ef_invest.columns = ['Col_' + str(i) if 3 <= i <= 39 else x for i, x in enumerate(ef_invest.columns, 1)]
ef_invest

#Reset index
ef_invest = ef_invest.reset_index()

#Delete old index
ef_invest = ef_invest.drop(labels=['index'], axis=1)

#Delete old columns name
ef_invest = ef_invest.drop(labels=[0], axis=0)

#Export to CSV file
ef_invest.to_csv(r'//Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Efficiency and Return/investment.csv', index=False)
ef_invest
# Out:
#    Years Total Col_3 Col_4 Col_5 Col_6 Col_7  Col_8 Col_9 Col_10  ... Col_29  \
# 1   1995  26.4  15.6    14  12.8   7.7   8.1   78.9   9.7   10.2  ...      9
# 2   1996  27.1  16.9  25.2    16     8  12.3   64.5  11.4   11.8  ...     10
# 3   1997  29.5  19.5  30.6  13.8   9.1  14.1  109.4  21.8   17.8  ...   11.6
# 4   1998  31.3  22.7  29.2  15.2    12  12.7   14.8  19.8     17  ...     12
# 5   1999  31.7  25.1  32.1  15.1  10.6  19.3    200  24.3     20  ...   12.5
# 6   2000    32  23.8  36.8  19.1  12.7  19.5  177.5  22.7   37.5  ...   11.5
# 7   2001  31.2  24.9  35.8  18.2  12.1    18  171.4  17.7   27.7  ...   10.8
# 8   2002  29.6  28.7  20.8  19.7   8.6  17.8  103.7  20.8   41.3  ...   14.3
# 9   2003  27.2    27  16.6  19.4   7.4  18.6   74.8  17.5   38.3  ...   15.5
# 10  2004  26.8  28.3  15.5  18.9   6.9  18.1   53.5  16.5   35.7  ...   16.4
# 11  2005  26.7  26.9  15.8  18.1   6.8  16.6   24.2    17   41.3  ...   13.8
# ...

# %% [markdown]
# ### For the file (Degree of production processing total and by industry.xlsx)

# %%
#Import data using pandas
ef_degree_production=pd.read_excel(r"/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Efficiency and Return/Degree of production processing total and by industry.xlsx")
ef_degree_production
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                                 NaN
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Place the name "Years" on the row that i will have the columns name, then drop the rest of columns and rows
ef_degree_production.loc[ef_degree_production.index[6], 'Unnamed: 0'] = "Years"

#Delete all rows with data not relevant
ef_degree_production = ef_degree_production.drop(labels=range(0, 6), axis=0)

#Delete all rows with data not relevant
ef_degree_production = ef_degree_production.drop(labels=range(32, 54), axis=0)

#Delete all columns with NAN values
ef_degree_production = ef_degree_production.dropna(thresh=10, axis=1)

#Rename the columns name with the values of the row index 6 
ef_degree_production.rename(columns=ef_degree_production.iloc[0], inplace = True)

#Rename the columns by code "Col_" plus position
ef_degree_production.columns = ['Col_' + str(i) if 3 <= i <= 39 else x for i, x in enumerate(ef_degree_production.columns, 1)]
ef_degree_production

#Reset index
ef_degree_production = ef_degree_production.reset_index()

#Delete old index
ef_degree_production = ef_degree_production.drop(labels=['index'], axis=1)

#Delete old columns name
ef_degree_production = ef_degree_production.drop(labels=[0], axis=0)

#Export to CSV file
ef_degree_production.to_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Efficiency and Return/degree_production.csv', index=False)
ef_degree_production
# Out:
#    Years Total Col_3 Col_4 Col_5 Col_6 Col_7 Col_8 Col_9 Col_10  ... Col_30  \
# 1   1995  0.46  0.62  0.61  0.16  0.33  0.33  0.05   0.3   0.43  ...   0.38
# 2   1996  0.45   0.6  0.57  0.17  0.34  0.34  0.07   0.3   0.43  ...   0.41
# 3   1997  0.45  0.58  0.58  0.18  0.33  0.35  0.08  0.29   0.41  ...   0.44
# 4   1998  0.46  0.58  0.59   0.2  0.33  0.34  0.13  0.26    0.4  ...   0.47
# 5   1999  0.46  0.56  0.58  0.22  0.35  0.34  0.07  0.26    0.4  ...   0.49
# 6   2000  0.46  0.56  0.56  0.21  0.33  0.34  0.06  0.24   0.39  ...   0.54
# 7   2001  0.46  0.55  0.54  0.22  0.33  0.34  0.06  0.25   0.39  ...   0.52
# 8   2002  0.47  0.54  0.52  0.23  0.35  0.34  0.05  0.25   0.41  ...   0.51
# 9   2003  0.48  0.54  0.51  0.24  0.35  0.32  0.06  0.24   0.41  ...    0.5
# 10  2004  0.47  0.53  0.52  0.24  0.35  0.31  0.08  0.23   0.41  ...    0.5
# 11  2005  0.47  0.51  0.51  0.24  0.35  0.33   0.1  0.22   0.41  ...   0.51
# ...

# %% [markdown]
# ## Internationalization
# ### For the file (Degree of exposure to international trade total and by product.xlsx)

# %%
#Import data using pandas
int_degree_exposure=pd.read_excel(r"/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Internationalization/Degree of exposure to international trade total and by product.xlsx")
int_degree_exposure
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                                 NaN
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Place the name "Years" on the row that i will have the columns name, then drop the rest of columns and rows
int_degree_exposure.loc[int_degree_exposure.index[6], 'Unnamed: 0'] = "Years"

#Delete all rows with data not relevant
int_degree_exposure = int_degree_exposure.drop(labels=range(0, 6), axis=0)

#Delete all rows with data not relevant
int_degree_exposure = int_degree_exposure.drop(labels=range(32, 54), axis=0)

#Delete all columns with NAN values
int_degree_exposure = int_degree_exposure.dropna(thresh=10, axis=1)

#Rename the columns name with the values of the row index 6 
int_degree_exposure.rename(columns=int_degree_exposure.iloc[0], inplace = True)

#Rename the columns by code "Col_" plus position
int_degree_exposure.columns = ['Col_' + str(i) if 3 <= i <= 39 else x for i, x in enumerate(int_degree_exposure.columns, 1)]
int_degree_exposure

#Reset index
int_degree_exposure = int_degree_exposure.reset_index()

#Delete old index
int_degree_exposure = int_degree_exposure.drop(labels=['index'], axis=1)

#Delete old columns name
int_degree_exposure = int_degree_exposure.drop(labels=[0], axis=0)

#Export to CSV file
int_degree_exposure.to_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Internationalization/Degree_exposure.csv', index=False)
int_degree_exposure
# Out:
#    Years  Total  Col_3  Col_4  Col_5  Col_6  Col_7  Col_8  Col_9 Col_10  ...  \
# 1   1995  26.05   23.6  78.61  30.82  63.81  44.82  54.63  70.46  54.25  ...
# 2   1996  26.01  23.63  77.93  31.03  65.01  44.12  47.53  69.81  59.71  ...
# 3   1997  26.89  26.54   78.6   32.9   67.1  46.42  44.21  71.65  59.96  ...
# 4   1998  27.56  28.39  69.25  34.85  69.28  46.21  44.88   73.7  67.45  ...
# 5   1999  27.86   26.5  74.58  36.27  71.22  47.34   42.7  75.78   76.1  ...
# 6   2000  29.02  28.32  81.51  37.47  72.46  50.73  44.29  79.97  79.03  ...
# 7   2001   28.1  30.31  79.53   37.1  73.34  50.09  41.79  78.05  82.71  ...
# 8   2002  27.82  30.67   79.2   38.6   73.2     52  46.73  79.89  83.09  ...
# 9   2003  27.87  30.19  81.39  39.02  72.84  52.36  45.74  81.43  84.31  ...
# 10  2004  28.43  30.85  85.43  39.73  72.23  52.89  42.16  82.85  84.41  ...
# 11  2005  28.32  31.46  88.13  40.95  71.64  52.43   44.2  85.94  84.96  ...
# ...

# %% [markdown]
# ### For the file (Export intensity total and by product.xlsx)

# %%
#Import data using pandas
int_export_intensity=pd.read_excel(r"/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Internationalization/Export intensity total and by product.xlsx")
int_export_intensity
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                                 NaN
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Place the name "Years" on the row that i will have the columns name, then drop the rest of columns and rows
int_export_intensity.loc[int_export_intensity.index[6], 'Unnamed: 0'] = "Years"

#Delete all rows with data not relevant
int_export_intensity = int_export_intensity.drop(labels=range(0, 6), axis=0)

#Delete all rows with data not relevant
int_export_intensity = int_export_intensity.drop(labels=range(32, 54), axis=0)

#Delete all columns with NAN values
int_export_intensity = int_export_intensity.dropna(thresh=10, axis=1)

#Rename the columns name with the values of the row index 6 
int_export_intensity.rename(columns=int_export_intensity.iloc[0], inplace = True)

#Rename the columns by code "Col_" plus position
int_export_intensity.columns = ['Col_' + str(i) if 3 <= i <= 39 else x for i, x in enumerate(int_export_intensity.columns, 1)]
int_export_intensity

#Reset index
int_export_intensity = int_export_intensity.reset_index()

#Delete old index
int_export_intensity = int_export_intensity.drop(labels=['index'], axis=1)

#Delete old columns name
int_export_intensity = int_export_intensity.drop(labels=[0], axis=0)

#Export to CSV file
int_export_intensity.to_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Internationalization/export_intensity.csv', index=False)
int_export_intensity
# Out:
#    Years  Total  Col_3  Col_4  Col_5  Col_6  Col_7  Col_8  Col_9 Col_10  ...  \
# 1   1995  12.11   3.47  29.65  11.54  47.32  33.71  33.94  29.04  13.76  ...
# 2   1996  11.98   3.32  26.46  11.71  48.04  32.09     25  28.39   17.6  ...
# 3   1997  12.28   4.63  25.85  12.69  49.51  33.98  23.36  31.01  17.88  ...
# 4   1998  12.33   4.53  18.12  12.86  50.82  32.98  22.52  31.01  21.35  ...
# 5   1999  12.24    4.6  17.21   13.1  52.91  33.29  19.74  32.95  26.15  ...
# 6   2000   12.8   5.44  17.45  14.42  53.18  36.31  18.73  38.89  31.56  ...
# 7   2001  12.37   6.66  15.06  13.89  53.95  35.04  15.58  35.61  32.79  ...
# 8   2002   12.6   7.26  15.97  15.28  53.64  36.87  18.76  37.92  33.84  ...
# 9   2003  13.03    7.9  16.62   15.6  53.46  37.68  21.32  40.96  32.66  ...
# 10  2004  13.04   8.56  24.64  15.94     52  37.63  20.24  43.88  30.74  ...
# 11  2005  12.82   8.96  27.63  17.26  50.81  37.21  21.14  48.63  31.44  ...
# ...

# %% [markdown]
# ### For the file (Import penetration rate in the domestic market total and by product.xlsx)

# %%
#Import data using pandas
int_import_penetracion=pd.read_excel(r"/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Internationalization/Import penetration rate in the domestic market total and by product.xlsx")
int_import_penetracion
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                               Years
# 6                                                 NaN
# 7                                                1995
# 8                                                1996
# 9                                                1997
# 10                                               1998
# 11                                               1999
# 12                                               2000
# 13                                               2001
# 14                                               2002
# 15                                               2003
# ...

# %%
#Place the name "Years" on the row that i will have the columns name, then drop the rest of columns and rows
int_import_penetracion.loc[int_import_penetracion.index[6], 'Unnamed: 0'] = "Years"

#Delete all rows with data not relevant
int_import_penetracion = int_import_penetracion.drop(labels=range(0, 6), axis=0)

#Delete all rows with data not relevant
int_import_penetracion = int_import_penetracion.drop(labels=range(32, 54), axis=0)

#Delete all columns with NAN values
int_import_penetracion = int_import_penetracion.dropna(thresh=10, axis=1)

#Rename the columns name with the values of the row index 6 
int_import_penetracion.rename(columns=int_import_penetracion.iloc[0], inplace = True)

#Rename the columns by code "Col_" plus position
int_import_penetracion.columns = ['Col_' + str(i) if 3 <= i <= 39 else x for i, x in enumerate(int_import_penetracion.columns, 1)]
int_import_penetracion

#Reset index
int_import_penetracion = int_import_penetracion.reset_index()

#Delete old index
int_import_penetracion = int_import_penetracion.drop(labels=['index'], axis=1)

#Delete old columns name
int_import_penetracion = int_import_penetracion.drop(labels=[0], axis=0)

#Export to CSV file
int_export_intensity.to_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Internationalization/import_penetracion.csv', index=False)
int_import_penetracion
# Out:
#    Years  Total  Col_3  Col_4  Col_5  Col_6  Col_7  Col_8  Col_9 Col_10  ...  \
# 1   1995  15.87   22.2  71.54   20.7  28.42  17.69  37.43  55.01  43.41  ...
# 2   1996  15.93  22.25  72.19  20.78  29.68  18.76  34.34  55.89  48.07  ...
# 3   1997  16.65  24.68  73.13  22.05  32.02  19.95  31.07  56.62  48.65  ...
# 4   1998  17.37  26.48  64.63  24.15  35.26  20.91  33.89  59.16  51.89  ...
# 5   1999   17.8  24.52  71.31  25.56  37.19  22.17  32.57  61.02  60.29  ...
# 6   2000   18.6  25.85  79.19  25.85   39.5  23.74  33.92  63.47  61.01  ...
# 7   2001  17.95  27.31  76.81  25.93  40.86  24.38  33.39  63.61  63.11  ...
# 8   2002  17.41  26.94  77.15  26.25   41.1  25.43  37.63   64.9  67.29  ...
# 9   2003  17.06  26.36  79.64  26.49  41.26  25.15  34.39  65.03  68.93  ...
# 10  2004  17.69  26.35  82.54  26.91  41.47  26.12  30.27  65.35   69.6  ...
# 11  2005  17.78  26.85  85.71  27.18  41.22  25.95  31.49  67.51  69.37  ...
# ...
