# %%
#First import usefull library

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Production Activities
# ### 1.1. For the file (Export of goods and services total and by product (2016).xlsx)

# %%
#Import csv file
pa_exports = pd.read_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic_Activities/Production_Activities/Export_of_goods.csv')

# %%
# Evolution of the total imports by years
plt.figure(figsize = (15,8))

ax = sns.barplot(x="Years", y="Total", data=pa_exports)

ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

fig = ax.get_figure()
fig.savefig(fr'barplot_pa_exports.png', facecolor = 'white')

plt.show()

# %%
#Distribution of the exports values by category
#To check if that outliers that should be removed

plt.figure(figsize = (20,10))

ax = pa_exports.boxplot(column=['Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7', 'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14', 'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21', 'Col_22', 'Col_23', 'Col_24', 'Col_25', 'Col_26', 'Col_27', 'Col_28', 'Col_29', 'Col_30', 'Col_31', 'Col_32', 'Col_33', 'Col_34', 'Col_35', 'Col_36', 'Col_37', 'Col_38'])

fig = ax.get_figure()
fig.savefig(fr'boxplot_pa_exports.png', facecolor = 'white')


plt.show()

# %%
#Heat map for correlation of industries on by exports

plt.figure(figsize = (15,8))

ax = sns.heatmap(pa_exports.corr())

fig = ax.get_figure()
fig.savefig(fr'heatmap_pa_exports.png', facecolor = 'white')

plt.show()

# %% [markdown]
# ### 1.2. For the file (Import of goods and services total and by product (2016).xlsx)

# %%
#Import csv file
pa_imports = pd.read_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic_Activities/Production_Activities/Import_of_goods.csv')

# %%
# Evolution of the total imports by years
plt.figure(figsize = (15,8))

ax = sns.barplot(x="Years", y="Total", data=pa_imports)

ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

fig = ax.get_figure()
fig.savefig(fr'barplot_pa_imports.png', facecolor = 'white')

plt.show()

# %%
#Distribution of the import values by category
#To check if that outliers that should be removed
plt.figure(figsize = (20,10))

ax = pa_imports.boxplot(column=['Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7', 'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14', 'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21', 'Col_22', 'Col_23', 'Col_24', 'Col_25', 'Col_26', 'Col_27', 'Col_28', 'Col_29', 'Col_30', 'Col_31', 'Col_32', 'Col_33', 'Col_34', 'Col_35', 'Col_36', 'Col_37', 'Col_38'])


fig = ax.get_figure()
fig.savefig(fr'boxplot_pa_imports.png', facecolor = 'white')

plt.show()

# %%
#Heat map for correlation of industries on by imports
plt.figure(figsize = (15,8))

ax = sns.heatmap(pa_imports.corr())

fig = ax.get_figure()
fig.savefig(fr'heatmap_pa_imports.png', facecolor = 'white')

plt.show()

# %% [markdown]
# ### 1.3. For the file (Gross value of production total and by industry (2016).xlsx)

# %%
#Import csv file
pa_production = pd.read_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic_Activities/Production_Activities/Production_of_goods.csv')

# %%
# Evolution of the total production by years
plt.figure(figsize = (15,8))

ax = sns.barplot(x='Years', y='Total', data=pa_production)

ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

fig = ax.get_figure()
fig.savefig(fr'barplot_pa_production.png', facecolor = 'white')

plt.show()

# %%
#Distribution of the import values by category
#To check if that outliers that should be removed
plt.figure(figsize = (20,10))

ax = pa_production.boxplot(column=['Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7', 'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14', 'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21', 'Col_22', 'Col_23', 'Col_24', 'Col_25', 'Col_26', 'Col_27', 'Col_28', 'Col_29', 'Col_30', 'Col_31', 'Col_32', 'Col_33', 'Col_34', 'Col_35', 'Col_36', 'Col_37', 'Col_38'])

fig = ax.get_figure()
fig.savefig(fr'boxplot_pa_production.png', facecolor = 'white')

plt.show()

# %%
#Heat map for correlation of industries on by production
plt.figure(figsize = (15,8))

ax = sns.heatmap(pa_production.corr())

fig = ax.get_figure()
fig.savefig(fr'heatmap_pa_production.png', facecolor = 'white')

plt.show()

# %% [markdown]
# ## 2. Efficiency and Return
# ### 2.1. For the file (Apparent labour productivity total and by industry.xlsx)

# %%
#Import csv file
ef_productivity=pd.read_csv(r"/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic_Activities/Efficiency_and _Return/labour_productivity.csv")

# %%
# Evolution of the total production by years
plt.figure(figsize = (15,8))

ax = sns.barplot(x="Years", y="Total", data=ef_productivity)

ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

fig = ax.get_figure()
fig.savefig(fr'barplot_ef_productivity.png', facecolor = 'white')

plt.show()

# %%
#Distribution of the production values by category
#To check if that outliers that should be removed
plt.figure(figsize = (20,10))

ax = ef_productivity.boxplot(column=['Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7', 'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14', 'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21', 'Col_22', 'Col_23', 'Col_24', 'Col_25', 'Col_26', 'Col_27', 'Col_28', 'Col_29', 'Col_30', 'Col_31', 'Col_32', 'Col_33', 'Col_34', 'Col_35', 'Col_36', 'Col_37', 'Col_38'])

fig = ax.get_figure()
fig.savefig(fr'boxplot_ef_productivity.png', facecolor = 'white')

plt.show()

# %%
#Heat map for correlation of industries on by production
plt.figure(figsize = (15,8))

ax = sns.heatmap(ef_productivity.corr())

fig = ax.get_figure()
fig.savefig(fr'heatmap_ef_productivity.png', facecolor = 'white')

plt.show()

# %% [markdown]
# ### 2.2 For the file (Investment rate total and by industry.xlsx)

# %%
#Import csv file
ef_invest = pd.read_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic_Activities/Efficiency_and _Return/investment.csv')

# %%
# Evolution of the investment production by years
plt.figure(figsize = (15,8))

ax = sns.barplot(x="Years", y="Total", data=ef_invest)

ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

fig = ax.get_figure()
fig.savefig(fr'barplot_ef_invest.png', facecolor = 'white')

plt.show()

# %%
#To check if that outliers that should be removed
#Distribution of the investment production values by category
plt.figure(figsize = (20,10))

ax = ef_invest.boxplot(column=['Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7', 'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14', 'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21', 'Col_22', 'Col_23', 'Col_24', 'Col_25', 'Col_26', 'Col_27', 'Col_28', 'Col_29', 'Col_30', 'Col_31', 'Col_32', 'Col_33', 'Col_34', 'Col_35', 'Col_36', 'Col_37'])

fig = ax.get_figure()
fig.savefig(fr'boxplot_ef_invest.png', facecolor = 'white')

plt.show()

# %%
#Heat map for correlation of investment production
plt.figure(figsize = (15,8))

ax = sns.heatmap(ef_invest.corr())

fig = ax.get_figure()
fig.savefig(fr'heatmap_ef_invest.png', facecolor = 'white')

plt.show()

# %% [markdown]
# ### 2.3. For the file (Degree of production processing total and by industry.xlsx)

# %%
#Import csv file
ef_degree_production = pd.read_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic_Activities/Efficiency_and _Return/degree_production.csv')

# %%
# Evolution of the production by years
plt.figure(figsize = (15,8))

ax = sns.barplot(x="Years", y="Total", data=ef_degree_production)

ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

fig = ax.get_figure()
fig.savefig(fr'barplot_ef_degree_production.png', facecolor = 'white')


plt.show()

# %%
#To check if that outliers that should be removed
#Distribution of the production values by category
plt.figure(figsize = (20,10))

ax = ef_degree_production.boxplot(column=['Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7', 'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14', 'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21', 'Col_22', 'Col_23', 'Col_24', 'Col_25', 'Col_26', 'Col_27', 'Col_28', 'Col_29', 'Col_30', 'Col_31', 'Col_32', 'Col_33', 'Col_34', 'Col_35', 'Col_36', 'Col_37', 'Col_38'])

fig = ax.get_figure()
fig.savefig(fr'boxplot_ef_degree_production.png', facecolor = 'white')

plt.show()

# %%
#Heat map for correlation of production
plt.figure(figsize = (15,8))

ax = sns.heatmap(ef_degree_production.corr())

fig = ax.get_figure()
fig.savefig(fr'heatmap_ef_degree_production.png', facecolor = 'white')

plt.show()

# %% [markdown]
# ## 3. Internationalization
# ### 3.1. For the file (Degree of exposure to international trade total and by product.xlsx)

# %%
#Import csv file
int_degree_exposure = pd.read_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic_Activities/Internationalization/Degree_exposure.csv')

# %%
# Evolution of the exposure to international trade by years
plt.figure(figsize = (15,8))

ax = sns.barplot(x="Years", y="Total", data=int_degree_exposure)

ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

fig = ax.get_figure()
fig.savefig(fr'barplot_int_degree_exposure.png', facecolor = 'white')

plt.show()

# %%
#To check if that outliers that should be removed
#Distribution of the exposure to international trade by category
plt.figure(figsize = (20,10))

ax = int_degree_exposure.boxplot(column=['Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7', 'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14', 'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21', 'Col_22', 'Col_23', 'Col_24', 'Col_25', 'Col_26', 'Col_27', 'Col_28', 'Col_29', 'Col_30', 'Col_31', 'Col_32', 'Col_33', 'Col_34', 'Col_35', 'Col_36', 'Col_37', 'Col_38'])

fig = ax.get_figure()
fig.savefig(fr'boxplot_int_degree_exposure.png', facecolor = 'white')


plt.show()

# %%
#Heat map for correlation of exposure to international trade
plt.figure(figsize = (15,8))

ax = sns.heatmap(int_degree_exposure.corr())

fig = ax.get_figure()
fig.savefig(fr'heatmap_int_degree_exposure.png', facecolor = 'white')


plt.show()

# %% [markdown]
# ### 3.2  For the file (Export intensity total and by product.xlsx)

# %%
#Import csv file
int_export_intensity = pd.read_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic_Activities/Internationalization/export_intensity.csv')

# %%
# Evolution of the export intensity by years
plt.figure(figsize = (15,8))

ax = sns.barplot(x="Years", y="Total", data=int_export_intensity)

ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

fig = ax.get_figure()
fig.savefig(fr'barplot_int_export_intensity.png', facecolor = 'white')

plt.show()

# %%
#To check if that outliers that should be removed
#Distribution of the export intensity by category
plt.figure(figsize = (20,10))

ax = int_export_intensity.boxplot(column=['Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7', 'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14', 'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21', 'Col_22', 'Col_23', 'Col_24', 'Col_25', 'Col_26', 'Col_27', 'Col_28', 'Col_29', 'Col_30', 'Col_31', 'Col_32', 'Col_33', 'Col_34', 'Col_35', 'Col_36', 'Col_37', 'Col_38'])

fig = ax.get_figure()
fig.savefig(fr'boxplot_int_export_intensity.png', facecolor = 'white')

plt.show()

# %%
#Heat map for correlation of export intensity
plt.figure(figsize = (15,8))

ax = sns.heatmap(int_export_intensity.corr())

fig = ax.get_figure()
fig.savefig(fr'heatmap_int_export_intensity.png', facecolor = 'white')

plt.show()

# %% [markdown]
# ### 3.3 For the file (Import penetration rate in the domestic market total and by product.xlsx)

# %%
#Import csv file
int_import_penetracion = pd.read_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic_Activities/Internationalization/import_penetracion.csv')

# %%
# Evolution of the import penetration by years
plt.figure(figsize = (15,8))

ax = sns.barplot(x="Years", y="Total", data=int_import_penetracion)

ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

fig = ax.get_figure()
fig.savefig(fr'barplot_int_import_penetracion.png', facecolor = 'white')

plt.show()

# %%
#To check if that outliers that should be removed
#Distribution of the import penetration by category
plt.figure(figsize = (20,10))

ax = int_import_penetracion.boxplot(column=['Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7', 'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14', 'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21', 'Col_22', 'Col_23', 'Col_24', 'Col_25', 'Col_26', 'Col_27', 'Col_28', 'Col_29', 'Col_30', 'Col_31', 'Col_32', 'Col_33', 'Col_34', 'Col_35', 'Col_36', 'Col_37', 'Col_38'])

fig = ax.get_figure()
fig.savefig(fr'boxplot_int_import_penetracion.png', facecolor = 'white')

plt.show()

# %%
#Heat map for correlation of import penetration
plt.figure(figsize = (15,8))

ax = sns.heatmap(int_import_penetracion.corr())

fig = ax.get_figure()
fig.savefig(fr'heatmap_int_import_penetracion.png', facecolor = 'white')

plt.show()
