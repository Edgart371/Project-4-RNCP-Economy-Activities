# %%
#First import usefull library

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pa_exports = pd.read_csv(r'/Users/edgartome_1/IronHack/IronProjects/Project4/Data_Economic Activities/Production Activities/Export_of_goods.csv')

# %%
pa_exports
# Out:
#     Years    Total   Col_3  Col_4   Col_5   Col_6   Col_7   Col_8   Col_9  \
# 0    1995  20739.8   222.2  257.7  1201.4  5170.8  1865.2   552.1   743.0
# 1    1996  21916.8   224.5  214.4  1306.5  5428.9  1718.1   430.6   714.4
# 2    1997  24341.6   289.8  240.3  1413.6  5864.1  1954.9   472.2   884.3
# 3    1998  26254.6   290.2  172.6  1480.4  6038.2  2062.9   359.5   856.9
# 4    1999  27488.5   299.8  166.2  1545.4  6074.8  2130.7   393.9   881.8
# 5    2000  31384.6   360.0  183.2  1761.4  6275.2  2654.4   620.4  1174.5
# 6    2001  32049.8   450.7  173.4  1799.6  6446.2  2527.6   492.0  1039.5
# 7    2002  33406.7   488.0  165.9  1981.6  6237.5  2575.4   531.2  1127.5
# 8    2003  35003.8   523.2  160.8  2021.5  5903.3  2628.1   648.3  1285.1
# 9    2004  36837.8   592.6  266.3  2146.7  5573.3  2627.2   763.6  1545.2
# 10   2005  37637.5   594.2  325.3  2341.0  5006.0  2632.0  1130.8  1804.8
# 11   2006  44734.8   664.6  549.7  2723.1  5266.0  2930.7  1697.2  2033.8
# ...

# %%
#
plt.figure(figsize = (15,8))
ax = sns.boxplot(x="Years", y="Total", data=pa_exports)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# <AxesSubplot:xlabel='Years', ylabel='Total'>

# %% [markdown]
# ## No outliers on the total value for Production Activities Export of goods

# %%
#Explain outliers no to remove!!

plt.figure(figsize = (20,10))
pa_exports.boxplot(column=['Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7', 'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14', 'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21', 'Col_22', 'Col_23', 'Col_24', 'Col_25', 'Col_26', 'Col_27', 'Col_28', 'Col_29', 'Col_30', 'Col_31', 'Col_32', 'Col_33', 'Col_34', 'Col_35', 'Col_36', 'Col_37', 'Col_38', 'Col_39'])
# Out:
# <AxesSubplot:>

# %%
#Col_20 "Constructions and construction works"
plt.figure(figsize = (15,8))
ax = sns.boxplot(x="Years", y="Col_20", data=pa_exports)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, '1995'),
#  Text(1, 0, '1996'),
#  Text(2, 0, '1997'),
#  Text(3, 0, '1998'),
#  Text(4, 0, '1999'),
#  Text(5, 0, '2000'),
#  Text(6, 0, '2001'),
#  Text(7, 0, '2002'),
#  Text(8, 0, '2003'),
#  Text(9, 0, '2004'),
#  Text(10, 0, '2005'),
#  Text(11, 0, '2006'),
#  Text(12, 0, '2007'),
#  Text(13, 0, '2008'),
#  Text(14, 0, '2009'),
#  Text(15, 0, '2010'),
#  Text(16, 0, '2011'),
#  Text(17, 0, '2012'),
#  Text(18, 0, '2013'),
#  Text(19, 0, '2014'),
#  Text(20, 0, '2015'),
#  Text(21, 0, '2016'),
#  Text(22, 0, '2017'),
#  Text(23, 0, '2018'),
#  Text(24, 0, '2019')]

# %%
plt.figure(figsize = (15,8))

sns.displot(x="Years", y="Total", data=pa_exports)

# %%
#Correlation
pa_exports.corr()
# Out:
#            Years     Total     Col_3     Col_4     Col_5     Col_6     Col_7  \
# Years   1.000000  0.987461  0.987227  0.907537  0.985683  0.447782  0.978047
# Total   0.987461  1.000000  0.989299  0.914360  0.983638  0.516063  0.988735
# Col_3   0.987227  0.989299  1.000000  0.894624  0.980229  0.501280  0.973503
# Col_4   0.907537  0.914360  0.894624  1.000000  0.934230  0.288743  0.889460
# Col_5   0.985683  0.983638  0.980229  0.934230  1.000000  0.464471  0.969010
# Col_6   0.447782  0.516063  0.501280  0.288743  0.464471  1.000000  0.560722
# Col_7   0.978047  0.988735  0.973503  0.889460  0.969010  0.560722  1.000000
# Col_8   0.914301  0.920357  0.898092  0.949417  0.952068  0.395481  0.906312
# Col_9   0.970068  0.978471  0.956977  0.953834  0.973972  0.392118  0.966077
# Col_10  0.967258  0.967351  0.973960  0.864445  0.969350  0.611531  0.965911
# Col_11  0.993811  0.993042  0.984867  0.929381  0.992316  0.447737  0.980065
# ...

# %%
#Heat map for correlation of industries on by exports

plt.figure(figsize = (15,8))

sns.heatmap(pa_exports.corr())
# Out:
# <AxesSubplot:>

# %%
import phik

# %%
ex = pa_exports.phik_matrix(['Years', 'Total', 'Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7', 'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14', 'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21', 'Col_22', 'Col_23', 'Col_24', 'Col_25', 'Col_26', 'Col_27', 'Col_28', 'Col_29', 'Col_30', 'Col_31', 'Col_32', 'Col_33', 'Col_34', 'Col_35', 'Col_36', 'Col_37', 'Col_38', 'Col_39'])

# %%
ex
# Out:
#            Years     Total     Col_3     Col_4     Col_5     Col_6     Col_7  \
# Years   1.000000  0.922587  0.970408  0.692948  0.937145  0.705949  0.875791
# Total   0.922587  1.000000  0.962243  0.771242  0.843013  0.551493  0.827589
# Col_3   0.970408  0.962243  1.000000  0.707219  0.916765  0.600580  0.810796
# Col_4   0.692948  0.771242  0.707219  1.000000  0.628709  0.459185  0.831897
# Col_5   0.937145  0.843013  0.916765  0.628709  1.000000  0.732618  0.879363
# Col_6   0.705949  0.551493  0.600580  0.459185  0.732618  1.000000  0.705672
# Col_7   0.875791  0.827589  0.810796  0.831897  0.879363  0.705672  1.000000
# Col_8   0.630341  0.659476  0.400884  0.883684  0.793896  0.662069  0.725067
# Col_9   0.810535  0.799141  0.795146  0.838103  0.812355  0.744908  0.939791
# Col_10  0.757650  0.837370  0.762722  0.751852  0.788377  0.683007  0.921629
# Col_11  0.924483  0.970635  0.900654  0.644009  0.962890  0.656297  0.756588
# ...

# %%
plt.figure(figsize = (15,8))
sns.heatmap(ex)
# Out:
# <AxesSubplot:>
